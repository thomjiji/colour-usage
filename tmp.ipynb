# %%
import numpy as np
import matplotlib.pyplot as plt
import colour.plotting

colour.utilities.filter_warnings(*[True] * 4)

COLOUR_STYLE = colour.plotting.colour_style()

MY_STYLE = {
    "figure.dpi": 144,
    "font.size": 14,
    "axes.titlepad": 16 * 0.75,
}

plt.style.use([COLOUR_STYLE, MY_STYLE])

FIGURE, AXES = colour.plotting.plot_RGB_colourspaces_in_chromaticity_diagram_CIE1931(
    ["name"], title="", diagram_opacity=0.25, show_spectral_locus=False, legend=False
)

plt.show()

# %%
figure, axes = colour.plotting.artist()

x = np.linspace(-10, 10, 1000)
y = cs.cctf_encoding(0.18 * 2**x)
axes.plot(x, y)

settings = {
    'title': '',
    'bounding_box': (-10, 10, 0, 1),
    'x_label': 'Stops Above/Below 18% grey',
    'y_label': curve,
    'legend': False,
}

colour.plotting.render(**settings)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 figure, axes = colour.plotting.artist()
#       3 x = np.linspace(-10, 10, 1000)
# ----> 4 y = cs.cctf_encoding(0.18 * 2**x)
#       5 axes.plot(x, y)
#       7 settings = {
#       8     'title': '',
#       9     'bounding_box': (-10, 10, 0, 1),
#    (...)
#      12     'legend': False,
#      13 }
#
# NameError: name 'cs' is not defined
